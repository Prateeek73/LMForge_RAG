# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.device_count())  # Should return the number of GPUs
print(torch.cuda.get_device_name(0))  # Should show the GPU model
# Out:
# True
# 1
# NVIDIA GB10
# /home/spark/anaconda3/envs/lmforge/lib/python3.10/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(

# %%
import transformers
import torch
import os
import json
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM
import logging
import time
from datetime import timedelta, datetime
import pandas as pd
from dotenv import load_dotenv
import shutil 

import evaluate
from sentence_transformers import SentenceTransformer, util
import numpy as np

# Load environment variables
load_dotenv(dotenv_path="../../.env") # path is relative to this script, adjust as needed

run_id = "LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct"  # <- Change this manually for each experiment
batch_size = 10  # <- Change this manually for each experiment

# %%
from transformers.utils import LossKwargs

# %%
import logging
logging.basicConfig(filename='generation.log', level=logging.INFO)
logging.info(f"Run ID: {run_id}")

# %%
# setting huggingface token
login(token=os.getenv("#"))

# os.environ["HF_HOME"] = "D:/huggingface_cache" 
# os.environ["TRANSFORMERS_CACHE"] = "D:/huggingface_cache"
# os.environ["HUGGINGFACE_HUB_CACHE"] = "D:/huggingface_cache"

# print("HF_HOME:", os.getenv("HF_HOME"))
# print("TRANSFORMERS_CACHE:", os.getenv("TRANSFORMERS_CACHE"))
# print("HUGGINGFACE_HUB_CACHE:", os.getenv("HUGGINGFACE_HUB_CACHE"))

# logging.info(f"HF_HOME: {os.getenv('HF_HOME')}")
# logging.info(f"TRANSFORMERS_CACHE: {os.getenv('TRANSFORMERS_CACHE')}")
# logging.info(f"HUGGINGFACE_HUB_CACHE: {os.getenv('HUGGINGFACE_HUB_CACHE')}")

# transformers.utils.hub.TRANSFORMERS_CACHE = "D:/huggingface_cache"
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model_name = "microsoft/Phi-4-mini-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float16, device_map="cuda", trust_remote_code=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
chunk_sizes = [128, 256, 512, 1024]
questions_num = 2
max_token_list = [128,256,512,1024,2048]

# %%
results_df = pd.DataFrame(columns=[
    "chunk_size", "questions_num", "qa_count_mismatch", "total_questions", "token_Size",
    "total_chunks", "success_count", "fail_count",
    "elapsed_time"
])

# %%
def power_analysis(chunk_size, max_tokens, qa_results,substring_date,elapsed_time):
    """
    Perform power analysis based on the provided parameters for the current run.
    """
    
    # https://huggingface.co/spaces/evaluate-metric/bertscore
    # https://huggingface.co/tasks/sentence-similarity
    # 1 Metric: ROUGE
    rouge = evaluate.load("rouge")

    originals = []
    generations = []

    for doc in qa_results.values():
        for item in doc:
            chunk = item.get("chunk")
            qa_pairs = item.get("qa_pairs", [])
            if not chunk or not isinstance(qa_pairs, list):
                continue  # Skip if chunk is missing or qa_pairs is not a list
            for pair in qa_pairs:
                answer = pair.get("answer") if isinstance(pair, dict) else None
                if answer:  # Only add if answer exists and is not None/empty
                    originals.append(str(chunk))
                    generations.append(str(answer))


    scores = rouge.compute(predictions=generations, references=originals)
    print(f"ROUGE Scores: {scores}")
    logging.info(f"ROUGE Scores: {scores} for chunk_size {chunk_size}, max_tokens {max_tokens}, questions_num {questions_num}")

    # 2 Metric: BERTScore
    bertscore = evaluate.load("bertscore")
    bert_scores = bertscore.compute(predictions=generations, references=originals, model_type="bert-base-uncased", lang="en")
    P = bert_scores["precision"]
    R = bert_scores["recall"]
    F1 = bert_scores["f1"] 

    print(f"BERTScore: {bert_scores}")
    logging.info(f"BERTScore: {bert_scores} for chunk_size {chunk_size}, max_tokens {max_tokens}, questions_num {questions_num}")

    # 3 Metric: STS (Semantic Textual Similarity)
    sts_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
    original_embeddings = sts_model.encode(originals, convert_to_tensor=True) 
    generated_embeddings = sts_model.encode(generations, convert_to_tensor=True)
    sts_scores = util.pytorch_cos_sim(original_embeddings, generated_embeddings).diagonal().cpu().tolist()

    print(f"STS Scores: {sts_scores}")
    logging.info(f"STS Scores: {sts_scores} for chunk_size {chunk_size}, max_tokens {max_tokens}, questions_num {questions_num}")

    # save the scores to a CSV file
    scores_df = pd.DataFrame({
        "chunk_size": [chunk_size],
        "max_tokens": [max_tokens],
        "questions_num": [questions_num],
        "rouge1": [scores["rouge1"]],
        "rouge2": [scores["rouge2"]],
        "rougeL": [scores["rougeL"]],
        "rougeLsum": [scores["rougeLsum"]],
        "bert_score_P": [np.mean(P)],
        "bert_score_R": [np.mean(R)],
        "bert_score_F1": [np.mean(F1)],
        "sts_score": [np.mean(sts_scores)],
        "substring_date": [substring_date],
        "elapsed_time": [elapsed_time],
    })
    
    print("Scores saved to scores.csv")   
    logging.info(f"Scores saved to scores.csv for chunk_size {chunk_size}, max_tokens {max_tokens}, questions_num {questions_num}")
    return scores_df

# %% [markdown]
# # Convert logs to Panda

# %%
def build_prompt(chunk, questions_num):
    return f"""
Generate {questions_num} question-answer pairs based on the following text segment. 
Return the result in valid JSON format as a list of objects.

Text Segment:

{chunk}

Response Format:
[
    {{"question": "generated question", "answer": "generated Answer"}},
]

Question answers should be at least 250 words long.

Do NOT include any explanation or preamble before or after the JSON output.
Return ONLY valid JSON output.

Answer:
    """

# %%
def load_data(chunk_size):
    path = f"../Spring25/Generate_Paragraphs/Results/extracted_chunks_{chunk_size}_overlap.json"
    if not os.path.exists(path):
        print(f"Missing input file: {path}, skipping.")
        logging.info(f"Missing input file: {path}, skipping.")
        return None
    with open(path, "r", encoding="utf-8") as file:
        return json.load(file)

# %%
def update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, key, value):
    if os.path.exists(detailed_tracker_path):
        detailed_tracker_df = pd.read_csv(detailed_tracker_path)
    else:
        detailed_tracker_df = pd.DataFrame(columns=["chunk_size", "questions_num", "qa_count_mismatch", "total_questions", 
            "max_tokens", "total_chunks", "success_count", "fail_count", "repeat_count", "duplicate_count", "elapsed_time"])
    # Check if the row already exists
    row_match = (
        (detailed_tracker_df["chunk_size"] == chunk_size) &
        (detailed_tracker_df["max_tokens"] == max_tokens) 
    )
    if not detailed_tracker_df.loc[row_match].empty:
        # Update the existing row
        detailed_tracker_df.loc[row_match, key] = value
    else:
        # Add a new row
        new_row = {
            "chunk_size": chunk_size,
            "max_tokens": max_tokens,
            "questions_num": 0,
            "qa_count_mismatch": 0,
            "total_questions": 0,
            "total_chunks": 0,
            "success_count": 0,
            "fail_count": 0,
            "repeat_count": 0,
            "duplicate_count": 0,
            "elapsed_time": 0
        }
        new_row[key] = value
        # Append the new row to the DataFrame
        detailed_tracker_df = pd.concat([detailed_tracker_df, pd.DataFrame([new_row])], ignore_index=True)
        
    # Save the updated DataFrame to CSV
    detailed_tracker_df.to_csv(detailed_tracker_path, index=False)
    print(f"Updated detailed tracker: {detailed_tracker_path}")
    logging.info(f"Updated detailed tracker: {detailed_tracker_path}")

# %%
# Set up device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# check if base directory exists, if not create it
if not os.path.exists(run_id):
    os.makedirs(run_id)
# Constants
check_point_path = f"{run_id}/qa_run_tracker.csv"
output_base = f"{run_id}/Generated_Results/microsoft-Phi-4-mini-instruct-spark"
detailed_tracker_path = f"{run_id}/qa_run_tracker_detailed.csv"

# Initialize tracker CSV if not present
if not os.path.exists(check_point_path):
    tracker_df = pd.DataFrame(columns=["chunk_size", "max_tokens", "questions_num", "completed"])
    for chunk_size in chunk_sizes:
        for max_tokens in max_token_list:
            tracker_df.loc[len(tracker_df)] = [chunk_size, max_tokens, questions_num, False]
    tracker_df.to_csv(check_point_path, index=False)
else:
    tracker_df = pd.read_csv(check_point_path)
    

# Results summary
results_df = pd.DataFrame(columns=[
    "chunk_size", "questions_num", "qa_count_mismatch", "total_questions",
    "max_tokens", "total_chunks", "success_count", "fail_count", "repeat_count",
    "duplicate_count", "elapsed_time"
])

# Check if detailed tracker exists, if not create it
if not os.path.exists(detailed_tracker_path):
    detailed_tracker_df = pd.DataFrame(columns=["chunk_size", "questions_num", "qa_count_mismatch", "total_questions", 
        "max_tokens", "total_chunks", "success_count", "fail_count", "repeat_count", "duplicate_count", "elapsed_time"])
    detailed_tracker_df.to_csv(detailed_tracker_path, index=False)
else:
    detailed_tracker_df = pd.read_csv(detailed_tracker_path)

for chunk_size in chunk_sizes:
    chunk_data = load_data(chunk_size)

    for max_tokens in max_token_list:
        row_match = (
            
            (tracker_df["chunk_size"] == chunk_size) &
            (tracker_df["max_tokens"] == max_tokens) &
            (tracker_df["questions_num"] == questions_num)
        )

        if tracker_df.loc[row_match, "completed"].any():
            print(f"Skipping chunk_size={chunk_size}, max_tokens={max_tokens} (already completed)")
            logging.info(f"Skipping chunk_size={chunk_size}, max_tokens={max_tokens} (already completed)")
            continue
        print(f"Processing chunk_size={chunk_size}, max_tokens={max_tokens}")
        logging.info(f"Processing chunk_size={chunk_size}, max_tokens={max_tokens}")

        output_file_path = f"{output_base}/generation_log_{chunk_size}_Token_{max_tokens}_Q{questions_num}.json"

        # Load existing results if file exists
        if os.path.exists(output_file_path):
            try:
                with open(output_file_path, "r", encoding="utf-8") as f:
                    qa_results = json.load(f)
            except json.JSONDecodeError:
                print("Warning: Output file is corrupted. Starting fresh.")
                logging.info("Warning: Output file is corrupted. Starting fresh.")
                qa_results = {}
        else:
            # Create the output directory if it doesn't exist
            os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
            qa_results = {}

        # Trackers
        total_chunks = 0
        success_count = 0
        fail_count = 0
        total_questions = 0
        qa_count_mismatch = 0
        repeat_count = 0
        duplicate_count = 0
        chunk_counter = 0

        start_time = time.time()

        for doc_name, chunks in chunk_data.items():
            if doc_name in qa_results and qa_results[doc_name]:
                print(f"Skipping {doc_name} (already processed)")
                logging.info(f"Skipping {doc_name} (already processed)")
                continue
            print(f"Processing {doc_name}...")
            logging.info(f"Processing {doc_name}...")
            # Initialize the document in the results dictionary
            qa_results[doc_name] = []

            for chunk in chunks[:900]:  # Adjust slice as needed
                total_chunks += 1
                update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "total_chunks", total_chunks)
                chunk_counter += 1
                prompt = build_prompt(chunk, questions_num)
                try:
                    inputs = tokenizer(prompt, return_tensors="pt").to(device)
                    with torch.no_grad():
                        output_tokens = model.generate(**inputs, max_new_tokens=max_tokens,pad_token_id=tokenizer.eos_token_id)
                    generated_tokens = output_tokens[0][len(inputs["input_ids"][0]):]
                    generated_text = tokenizer.decode(generated_tokens, skip_special_tokens=True)
                    print(generated_text)
                    qa_pairs = json.loads(generated_text)

                    if isinstance(qa_pairs, list):
                        qa_results[doc_name].append({
                            "chunk": chunk,
                            "qa_pairs": qa_pairs
                        })
                        success_count += 1
                        update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "success_count", success_count)
                        total_questions += len(qa_pairs)
                        update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "total_questions", total_questions)

                        if len(qa_pairs) != questions_num:
                            qa_count_mismatch += 1
                            update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "qa_count_mismatch", qa_count_mismatch)
                            logging.info(f"Warning: Expected {questions_num} questions, got {len(qa_pairs)}")
                        
                        #  question and answer are the same
                        for pair in qa_pairs:
                            if pair["question"] == pair["answer"]:
                                repeat_count += 1
                                update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "repeat_count", repeat_count)
                                logging.info(f"Warning: Question and answer are the same in {doc_name}")
                            # check for duplicates in the same chunk
                            if any(pair["question"] == p["question"] for p in qa_pairs if p != pair):
                                duplicate_count += 1
                                update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "duplicate_count", duplicate_count)
                                logging.info(f"Warning: Duplicate question in {doc_name}")
                    else:
                        fail_count += 1
                        update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "fail_count", fail_count)
                        logging.info(f"Warning: Invalid JSON format in {doc_name}: {generated_text}")

                except Exception as e:
                    print(f"Error processing chunk from {doc_name}: {e}")
                    logging.error(f"Error processing chunk from {doc_name}: {e}")
                    fail_count += 1
                    update_detailed_tracker(detailed_tracker_path,chunk_size, max_tokens, "fail_count", fail_count)
                    continue

                # Save every batch_size chunks
                if chunk_counter % batch_size == 0:
                    with open(output_file_path, "w", encoding="utf-8") as out_file:
                        json.dump(qa_results, out_file, indent=4, ensure_ascii=False)
                    print(f"Checkpoint saved at chunk {chunk_counter}")
                    logging.info(f"Checkpoint saved at chunk {chunk_counter}")

                    # update the detailed tracker
                    

            # Save after each document
            with open(output_file_path, "w", encoding="utf-8") as out_file:
                json.dump(qa_results, out_file, indent=4, ensure_ascii=False)
            print(f"Saved full doc: {doc_name}")
            logging.info(f"Saved full doc: {doc_name}")

        # Final save
        end_time = time.time()
        elapsed_time = timedelta(seconds=end_time - start_time)

        results_df.loc[len(results_df)] = [
            chunk_size, questions_num, qa_count_mismatch, total_questions,
            max_tokens, total_chunks, success_count, fail_count, repeat_count,
            duplicate_count, str(elapsed_time)
        ]

        print(f"Completed {chunk_size}, {max_tokens} | Time: {elapsed_time}")
        logging.info(f"Completed {chunk_size}, {max_tokens} | Time: {elapsed_time}")

        # Update tracker
        tracker_df.loc[row_match, "completed"] = True
        tracker_df.to_csv(check_point_path, index=False)

        scores_df = power_analysis(chunk_size, max_tokens, qa_results,run_id,elapsed_time)
        if os.path.exists(f"{output_base}/scores.csv"):
            scores_df.to_csv(f"{output_base}/scores.csv", mode='a', header=False, index=False)
        else:
            os.makedirs(f"{output_base}/scores", exist_ok=True)
            scores_df.to_csv(f"{output_base}/scores.csv", index=False)
        # save the results to a CSV file
        if os.path.exists(f"{output_base}/qa_generation_results.csv"):
            results_df.to_csv(f"{output_base}/qa_generation_results.csv", mode='a', header=False, index=False)
        else:
            os.makedirs(f"{output_base}/qa_generation_results", exist_ok=True)
            results_df.to_csv(f"{output_base}/qa_generation_results.csv", index=False)
        print(f"Results saved to {output_base}/qa_generation_results.csv")
        logging.info(f"Results saved to {output_base}/qa_generation_results.csv")


# Save summary CSV
csv_output_path = f"{output_base}/qa_generation_results_summary.csv"
results_df.to_csv(csv_output_path, index=False)
print(f"\nSummary saved to {csv_output_path}")
logging.info(f"\nSummary saved to {csv_output_path}")
# Out:
# Skipping chunk_size=128, max_tokens=128 (already completed)
# Skipping chunk_size=128, max_tokens=256 (already completed)
# Processing chunk_size=128, max_tokens=512
# Skipping Documents/Legal Aspects of Corporate Management and Finance.pdf (already processed)
# Processing Documents/PrinciplesofFinance-WEB.pdf...
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#         {
#             "question": "Who are the senior contributing authors of the Principles of Finance textbook published by OpenStax?",
#             "answer": "The senior contributing authors of the Principles of Finance textbook published by OpenStax are Julie Dahlquist from Texas Christian University and Raiford Knight from Florida Atlantic University. These authors have contributed their expertise and knowledge to the development of the textbook, ensuring that it provides a comprehensive and accurate overview of financial principles. Their involvement in the project highlights the collaborative effort of educators and professionals in the field of finance to create educational resources that are both informative and accessible to students."
#         },
#         {
#             "question": "Under what license is the textbook content produced by OpenStax licensed, and what does this license allow?",
#             "answer": "The textbook content produced by OpenStax is licensed under a Creative Commons Attribution 4.0 International License (CC BY 4.0). This license allows users to share (copy and redistribute the material in any medium or format) and adapt (remix, transform, and build upon the material) the content for any purpose, even commercially, as long as appropriate credit is given to OpenStax and the original authors. The license also requires that any derivative works be distributed under the same license. This open licensing model promotes the dissemination of knowledge and encourages the creation of derivative works, fostering a collaborative and innovative educational environment."
#         }
#     ]
#
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What are the requirements for attribution when redistributing the textbook in a digital format, including PDF and HTML?",
#          "answer": "When redistributing the textbook in a digital format, such as PDF and HTML, it is mandatory to retain the following attribution on every page: 'Access for free at openstax.org.' This requirement ensures that the source of the textbook is acknowledged, and it maintains the integrity of the open-access initiative by directing users to the original platform where the textbook is freely available."
#        },
#        {
#          "question": "What are the attribution requirements for redistributing part of the textbook in both digital and print formats?",
#          "answer": "Redistributing part of the textbook in both digital and print formats necessitates the inclusion of a specific attribution on every page. In digital formats, including PDF and HTML, the attribution 'Access for free at openstax.org' must be retained on every page view. For print formats, the same attribution 'Access for free at openstax.org' must be included on every physical printed page. This consistent attribution across all formats ensures that the source of the textbook is properly credited, and it supports the open-access model by guiding users to the original free access platform."
#        }
#     ]
#
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  {
#         "question": "What are the different formats in which the textbook 'Principles of Finance' is available for free, and what is the requirement for attribution when using it as a bibliographic reference?",
#         "answer": "The textbook 'Principles of Finance' is available for free in multiple formats, including PDF and HTML, as well as on every physical printed page. When using this textbook as a bibliographic reference, it is required to include the URL https://openstax.org/details/books/principles-finance in the citation. This ensures proper attribution and acknowledges the source of the information. For any questions regarding the licensing of this textbook, individuals are encouraged to contact support@openstax.org for assistance."
#     },
#     {
#         "question": "What are the trademarks associated with the textbook 'Principles of Finance' and which organization is responsible for them?",
#         "answer": "The trademarks associated with the textbook 'Principles of Finance' include the OpenStax name, OpenStax logo, OpenStax book covers, OpenStax CNX name, OpenStax CNX logo, Openstax Tutor name, Openstax Tutor logo, Connexions name, Connexions logo, Rice University name, and Rice University logo. These trademarks are owned by Rice University, which is responsible for them. The inclusion of these trademarks indicates the official association and endorsement of the textbook by Rice University, ensuring that the content is of high quality and meets academic standards."
#     }
# ]
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 4 column 6 (char 761)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  Please purchase the book from the publisher or the OpenStax website. The book is not available for free download or purchase from other sources. The book is copyrighted material and any reproduction, distribution, or transmission of the book without the prior written permission of the publisher is strictly prohibited. The book is available for purchase from the publisher's website or from authorized retailers. The book is also available in digital format, which can be purchased from the OpenStax website. The book is available in hardcover, paperback, and digital formats. The book is available in English and Spanish. The book is available for purchase in the United States, Canada, and Mexico. The book is available for purchase in the United Kingdom, Ireland, Australia, New Zealand, and South Africa. The book is available for purchase in India, China, Japan, and South Korea. The book is available for purchase in Brazil, Argentina, and Mexico. The book is available for purchase in France, Germany, Italy, Spain, and Switzerland. The book is available for purchase in Russia, Turkey, and the Middle East. The book is available for purchase in South America, Central America, and the Caribbean. The book is available for purchase in Africa, the Middle East, and Asia. The book is available for purchase in Europe. The book is available for purchase in the United States, Canada, and Mexico. The book is available for purchase in the United Kingdom, Ireland, Australia, New Zealand, and South Africa. The book is available for purchase in India, China, Japan, and South Korea. The book is available for purchase in Brazil, Argentina, and Mexico. The book is available for purchase in France, Germany, Italy, Spain, and Switzerland. The book is available for purchase in Russia, Turkey, and the Middle East. The book is available for purchase in South America, Central America, and the Caribbean. The book is available for purchase in Africa, the Middle East, and Asia. The book is available for purchase in Europe. The book is available for purchase in the United States, Canada, and Mexico. The book is available for purchase in the United Kingdom, Ireland, Australia, New Zealand, and South Africa. The book is available for purchase in India, China, Japan, and South Korea. The book is available for purchase in Brazil, Argentina, and Mexico. The book is available for purchase in France, Germany, Italy, Spain, and Switzerland. The book is available for purchase in Russia, Turkey, and the Middle East. The book is available for
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Expecting value: line 1 column 2 (char 1)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the primary mission of Rice University, and how do its initiatives like OpenStax, OpenStax CNX, and OpenStax Tutor support this mission?",
#          "answer": "The primary mission of Rice University is to excel in research, teaching, and contributing to the betterment of the world. This mission is supported by cultivating a diverse community of learning and discovery that produces leaders across various fields. Initiatives like OpenStax, OpenStax CNX, and OpenStax Tutor play a crucial role in fulfilling this mission by providing students with the necessary tools to complete their courses and achieve their educational goals. OpenStax offers free, peer-reviewed, openly licensed textbooks, which are essential resources for students, especially those who may not have access to expensive textbooks. OpenStax CNX provides a platform for creating and sharing high-quality educational content, including interactive learning materials, which enhance the teaching and learning experience. OpenStax Tutor, on the other hand, offers personalized tutoring services, helping students understand and master course content. These initiatives collectively support Rice University's commitment to undergraduate education by ensuring that all students, regardless of their background, have access to the resources they need to succeed academically and contribute to society as informed and capable leaders."
#        },
#        {
#          "question": "How does Rice University aim to cultivate a diverse community of learning and discovery, and what role do its initiatives play in producing leaders across various fields?",
#          "answer": "Rice University aims to cultivate a diverse community of learning and discovery by fostering an environment that values and encourages the contributions of individuals from various backgrounds and disciplines. This commitment to diversity is integral to the university's mission of producing leaders who can navigate and contribute to a complex and interconnected world. The university's initiatives, such as OpenStax, OpenStax CNX, and OpenStax Tutor, are instrumental in this process. By providing free, high-quality educational resources and personalized tutoring, these initiatives ensure that all students have the opportunity to access the tools they need to succeed academically. This inclusive approach to education helps to create a diverse student body that brings a wide range of perspectives and experiences to the university community. As students engage with these resources and benefit from the support they provide, they are better equipped to develop the skills and knowledge necessary to become leaders in their respective fields. The initiatives also foster a culture of innovation and collaboration, as students are encouraged to explore new ideas and work together to solve complex problems. In this way, Rice University's initiatives
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Unterminated string starting at: line 8 column 20 (char 1676)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "Which philanthropic partners are mentioned as supporters of OpenStax in the provided text segment?",
#          "answer": "The philanthropic partners mentioned as supporters of OpenStax in the provided text segment include Arnold Ventures, Chan Zuckerberg Initiative, Chegg, Inc., Arthur and Carlyse Ciocca Charitable Foundation, Digital Promise, Ann and John Doerr, Bill & Melinda Gates Foundation, Girard Foundation, Google Inc., The William and Flora Hewlett Foundation, The Hewlett-Packard Company, Intel Inc., and Rusty and John Jaggers. These partners are recognized for their generous contributions that help advance OpenStax's mission to improve educational access and learning for everyone. Their support is crucial in enabling OpenStax to provide high-quality, accessible educational resources to a wide audience. By partnering with these philanthropic organizations, OpenStax is able to continue its efforts in making education more inclusive and accessible, thereby positively impacting the learning experiences of students across various educational levels."
#        },
#        {
#          "question": "Where can one find the impact of the supporter community and the most updated list of partners for OpenStax?",
#          "answer": "The impact of the supporter community and the most updated list of partners for OpenStax can be found by visiting the website openstax.org/impact. This page is dedicated to showcasing the contributions and support from the philanthropic partners that are instrumental in advancing OpenStax's mission. By exploring this section, individuals can gain insights into how these partners are helping to improve educational access and learning for everyone. The website serves as a resource for understanding the significance of these partnerships and the positive changes they bring to the educational landscape."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 1901)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "Which foundation is associated with Brian D. Patterson USA-International Foundation?",
#          "answer": "The Brian D. Patterson USA-International Foundation is associated with the United States of America."
#        },
#        {
#          "question": "Who are the founders of the Calvin K. Kazanjian Economics Foundation?",
#          "answer": "The Calvin K. Kazanjian Economics Foundation was founded by Calvin K. Kazanjian."
#        }
#      ]
# }
#
# Answer:
#      [
#        {
#          "question": "Which foundation is associated with the United States of America?",
#          "answer": "The Brian D. Patterson USA-International Foundation is associated with the United States of America."
#        },
#        {
#          "question": "Who are the founders of the Calvin K. Kazanjian Economics Foundation?",
#          "answer": "The Calvin K. Kazanjian Economics Foundation was founded by Calvin K. Kazanjian."
#        }
#      ]
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 474)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What are the main topics covered in the 'Introduction to Finance' chapter of the book accessed through openstax.org?",
#          "answer": "The 'Introduction to Finance' chapter, accessible through openstax.org, delves into the foundational aspects of finance, starting with the significance of finance in an organizational context. It begins by posing the question 'Why It Matters,' emphasizing the critical role finance plays in the success and sustainability of organizations. The chapter is structured to provide a comprehensive understanding of finance, beginning with an exploration of what finance entails, labeled as 'What Is Finance?' This section likely introduces the reader to the basic concepts and definitions that underpin the field of finance, setting the stage for a deeper exploration of its functions and importance. Following this, the chapter progresses to 'The Role of Finance in an Organization,' where it presumably discusses how finance supports and drives the strategic objectives of an organization. This part of the chapter might cover topics such as financial planning, budgeting, investment decisions, and risk management, illustrating how these elements contribute to the overall health and growth of an organization. By covering these topics, the chapter aims to equip readers with a solid understanding of the fundamental principles of finance and its application in real-world scenarios, thereby highlighting its significance in both personal and professional contexts."
#        },
#        {
#          "question": "What features does the web view of the book on openstax.org offer to enhance the study experience?",
#          "answer": "The web view of the book on openstax.org offers several features designed to enhance the study experience for users. One of the key features is the ability to use online highlighting and note-taking tools. These tools allow students to mark important sections of the text, highlight key concepts, and take notes directly within the web view. This interactive approach to studying helps students to engage more deeply with the material, making it easier to review and retain information. Additionally, the flexibility of accessing the book online means that students can study at their own pace, choosing when and where they want to learn. This convenience is further supported by the fact that the books are free and flexible, available forever, which encourages continuous learning and exploration of financial principles. The combination of these features—highlighting, note-taking, and flexible access—creates a dynamic and user-friendly study environment that caters to the diverse needs of learners, ultimately fostering a more effective and personalized educational experience."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 2802)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the role of the Board of Directors in a company, and how does it relate to the relationship between shareholders and company management?",
#          "answer": "The Board of Directors plays a crucial role in a company's governance structure. It is responsible for overseeing the company's management and ensuring that the company's strategic goals align with the interests of its shareholders. The Board of Directors is elected by the shareholders and is tasked with making key decisions that affect the company's direction and operations. This includes approving major corporate actions, such as mergers and acquisitions, and setting the company's overall strategy. The Board of Directors also has a duty to monitor the company's performance and ensure that it is being managed in a way that maximizes shareholder value. The relationship between shareholders and company management is a key aspect of corporate governance. Shareholders, as the owners of the company, have a vested interest in its success and expect the company's management to act in their best interests. The Board of Directors serves as a bridge between the shareholders and the company's management, ensuring that the management's actions align with the shareholders' interests. The Board of Directors also has a responsibility to hold the company's management accountable for their actions and decisions. This includes monitoring the company's financial performance, evaluating the effectiveness of the company's management team, and ensuring that the company is being managed in a way that maximizes shareholder value. In summary, the Board of Directors plays a critical role in a company's governance structure, overseeing the company's management and ensuring that the company's strategic goals align with the interests of its shareholders. The relationship between shareholders and company management is a key aspect of corporate governance, and the Board of Directors serves as a bridge between the two, ensuring that the management's actions align with the shareholders' interests and holding the management accountable for their actions and decisions."
#        },
#        {
#          "question": "What are the agency issues that arise between shareholders and corporate boards, and how do they impact the relationship between shareholders and company management?",
#          "answer": "Agency issues arise when there is a conflict of interest between shareholders and corporate boards. Shareholders, as the owners of the company, have a vested interest in the company's success and expect the company's management to act in their best interests. However, corporate boards, which are responsible for overseeing the company's management, may have different priorities and objectives. This can lead to agency issues, as the board may make decisions that benefit themselves or other stakeholders, rather than the shareholders. For example, the board may prioritize short-term gains over long-term growth,
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Unterminated string starting at: line 8 column 20 (char 2401)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the role of the Board of Directors in a company, and how do agency issues between shareholders and corporate boards arise according to the text segment?",
#          "answer": "The role of the Board of Directors in a company is to oversee the management and ensure that the company's interests are aligned with those of its shareholders. The Board of Directors is responsible for making key decisions, setting strategic direction, and ensuring that the company is managed effectively and efficiently. Agency issues between shareholders and corporate boards arise when there is a conflict of interest between the two parties. Shareholders are the owners of the company and expect the Board of Directors to act in their best interests. However, the Board of Directors may have their own interests, which may not always align with those of the shareholders. This can lead to agency problems, where the Board of Directors may make decisions that benefit themselves rather than the shareholders. To mitigate these agency issues, companies can implement various measures such as performance-based compensation, regular communication with shareholders, and independent board members."
#        },
#        {
#          "question": "What are the key economic concepts covered in the text segment, and how do they relate to the functioning of businesses in domestic and global markets?",
#          "answer": "The key economic concepts covered in the text segment include microeconomics, macroeconomics, business cycles and economic activity, interest rates, foreign exchange rates, and sources and characteristics of economic data. Microeconomics focuses on the behavior of individual consumers and firms, while macroeconomics looks at the economy as a whole. Business cycles and economic activity refer to the fluctuations in economic activity over time, which can impact businesses in both domestic and global markets. Interest rates are the cost of borrowing money, which can affect businesses' investment decisions. Foreign exchange rates determine the value of one currency relative to another, which can impact businesses that operate in multiple countries. Sources and characteristics of economic data provide information about the economy, which can help businesses make informed decisions. These economic concepts are crucial for businesses to understand as they navigate domestic and global markets, as they can impact their operations, profitability, and overall success."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 2525)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the main difference between cash and accrual accounting as discussed in the text segment?",
#          "answer": "The main difference between cash and accrual accounting, as discussed in the text segment, lies in the timing of when revenues and expenses are recognized. Cash accounting recognizes revenues and expenses only when cash is actually received or paid, respectively. This method is straightforward but may not accurately reflect a company's financial position during periods of significant credit transactions. On the other hand, accrual accounting recognizes revenues when they are earned and expenses when they are incurred, regardless of when the cash transactions occur. This method provides a more accurate picture of a company's financial health by matching revenues with the expenses incurred to generate them, thus adhering to the matching principle. The accrual basis of accounting is essential for understanding the true economic activities of a company, as it reflects the company's obligations and resources at any given time, not just when cash changes hands."
#        },
#        {
#          "question": "How does the text segment describe the process of recognizing a sale and an expense in accrual accounting?",
#          "answer": "The text segment describes the process of recognizing a sale and an expense in accrual accounting as a method that adheres to the economic basis of transactions. In accrual accounting, a sale is recognized when the revenue is earned, which means that the company has delivered the goods or services to the customer, even if the cash has not yet been received. This is in contrast to cash accounting, where a sale is only recognized when the cash is received. Similarly, an expense is recognized when it is incurred, not necessarily when it is paid. This means that if a company receives goods or services on credit, it must recognize the expense at the time the goods or services are received, even if the payment will be made at a later date. This approach ensures that the financial statements reflect the company's financial activities and obligations during the period in which they occur, providing a more accurate and comprehensive view of the company's financial performance and position."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 2309)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the purpose of the Statement of Owner’s Equity as discussed in the text segment?",
#          "answer": "The Statement of Owner’s Equity, as mentioned in the text segment, serves to detail the changes in the owner's equity over a specific period. This statement is crucial for understanding how the owner's investment, withdrawals, and the net income or loss have impacted the equity in the business. It essentially bridges the gap between the income statement and the balance sheet by showing how the net income (or loss) from the income statement affects the owner's equity on the balance sheet. The statement of owner’s equity starts with the beginning equity balance, adds the net income or subtracts the net loss, and then subtracts any withdrawals made by the owner. The result is the ending equity balance, which is then reported on the balance sheet. This statement is particularly important for sole proprietorships and partnerships, where the owner's equity directly reflects the owner's stake in the business."
#        },
#        {
#          "question": "How does the Statement of Cash Flows relate to the Income Statement and Balance Sheet according to the text segment?",
#          "answer": "The Statement of Cash Flows, as outlined in the text segment, is a financial statement that provides a detailed analysis of a company's cash inflows and outflows over a specific period. It is closely related to both the Income Statement and the Balance Sheet. The Income Statement records revenues and expenses, which affect net income, but it does not provide information about cash transactions. The Balance Sheet, on the other hand, shows the company's assets, liabilities, and equity at a specific point in time, but it does not detail how those balances were achieved. The Statement of Cash Flows bridges this gap by showing how the net income (or loss) from the Income Statement and changes in the Balance Sheet accounts affect the company's cash position. It is divided into three sections: operating activities, investing activities, and financing activities. The operating activities section adjusts net income for non-cash transactions and changes in working capital. The investing activities section reflects cash spent on or received from investments in long-term assets. The financing activities section shows cash flows related to borrowing, repaying debt, issuing stock, and paying dividends. By analyzing the Statement of Cash Flows, stakeholders can understand how the company's operations, investment decisions, and financing activities impact its cash flow, providing a comprehensive view of the company's financial health."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 2703)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#         {
#             "question": "What is the primary focus of Chapter 6 in the provided text segment, and what are the key topics covered within it?",
#             "answer": "Chapter 6 primarily focuses on various financial ratios used to analyze a company's performance and financial health. The key topics covered within this chapter include Ratios, which are discussed in section 6.1, where the concept of condensing information into smaller pieces is introduced. Operating Efficiency Ratios are explored in section 6.2, providing insights into how effectively a company utilizes its assets to generate revenue. Liquidity Ratios, covered in section 6.3, assess a company's ability to meet its short-term obligations. Solvency Ratios, discussed in section 6.4, evaluate a company's long-term financial stability and its ability to meet long-term obligations. Market Value Ratios, in section 6.5, examine the market's perception of a company's value. Profitability Ratios and the DuPont Method, covered in section 6.6, delve into how well a company generates profit relative to its revenue, assets, and equity. The chapter concludes with a Summary, Key Terms, and additional resources such as CFA Institute references, Multiple Choice questions, Review Questions, Problems, and a Video Activity on the Time Value of Money."
#         },
#         {
#             "question": "What is the Time Value of Money (TVM) and what are the key concepts and methods associated with it as outlined in Chapter 7?",
#             "answer": "The Time Value of Money (TVM) is a financial concept that states that a dollar today is worth more than a dollar in the future due to its potential earning capacity. Chapter 7 delves into the importance of TVM and its basic principles. Section 7.1, 'Why It Matters,' emphasizes the significance of considering the timing of money, highlighting the preference for receiving money now rather than later. Section 7.2, 'Time Value of Money (TVM) Basics,' introduces the fundamental idea that money can earn interest over time, making it more valuable in the future. Section 7.3, 'Methods for Solving Time Value of Money Problems,' outlines various techniques for calculating the present and future values of money, including the use of financial calculators and formulas. Section 7.4, 'Applications of TVM in Finance,' discusses how TVM is applied in various financial scenarios, such as investment decisions, loan calculations, and retirement planning. The chapter concludes with
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Unterminated string starting at: line 8 column 23 (char 1524)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What are the key topics covered in Chapter 7 of the textbook, and how do they relate to the applications of TVM in finance?",
#          "answer": "Chapter 7 of the textbook, titled 'Applications of TVM in Finance,' delves into several key topics that are crucial for understanding the practical applications of Time Value of Money (TVM) in the financial sector. The chapter begins with a summary that likely encapsulates the main points discussed throughout the chapter. Following the summary, the chapter introduces key terms that are essential for grasping the concepts related to TVM and its applications in finance. These terms may include definitions and explanations of financial instruments and concepts such as perpetuities, annuities, loan amortization, and the differences between stated and effective interest rates.
#
# The chapter then proceeds to discuss the importance of TVM in finance, highlighting why it matters for financial professionals and investors. This section likely emphasizes the significance of understanding the time value of money when making investment decisions, evaluating financial products, and managing personal finances.
#
# Subsequent sections of the chapter provide a detailed exploration of various applications of TVM. For instance, 'Perpetuities' (8.1) examines the concept of perpetuities, which are financial instruments that provide a stream of cash flows indefinitely. This section likely explains how perpetuities are valued and their relevance in finance.
#
# 'Annuities' (8.2) discusses annuities, which are financial products that offer a series of payments over time. The chapter likely covers the calculation of the present and future values of annuities, as well as their applications in retirement planning and other financial scenarios.
#
# 'Loan Amortization' (8.3) explores the process of loan repayment, where the borrower makes regular payments to reduce the principal amount and interest over time. This section likely explains how to calculate the amortization schedule and the impact of different payment strategies on the loan balance.
#
# 'Stated versus Effective Rates' (8.4) compares the nominal interest rate (stated rate) with the effective interest rate, which takes into account the effects of compounding. This section likely explains the importance of understanding the effective rate when comparing financial products and making investment decisions.
#
# 'Equal Payments with a Financial Calculator and Excel' (8.5) provides practical guidance on how to use financial calculators and Excel to solve problems related to equal multiple payments. This section likely includes examples and step-by-step instructions for calculating the present and future values
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Invalid control character at: line 4 column 701 (char 861)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What are the key characteristics of bonds that are essential for bond valuation as discussed in the text segment?",
#          "answer": "The key characteristics of bonds essential for bond valuation include the bond's face value, coupon rate, maturity date, and yield to maturity. The face value, also known as the par value, is the amount that the bond issuer agrees to pay back to the bondholder at maturity. The coupon rate determines the periodic interest payments that the bondholder will receive, typically paid semi-annually or annually. The maturity date is the date on which the bond will mature, and the issuer will repay the face value to the bondholder. Yield to maturity (YTM) is the total return anticipated on a bond if the bond is held until it matures, taking into account the bond's current market price, coupon payments, and time to maturity. Understanding these characteristics is crucial for accurately valuing bonds, as they directly impact the bond's price and the investor's return."
#        },
#        {
#          "question": "How does the yield curve assist in bond valuation according to the text segment?",
#          "answer": "The yield curve is a graphical representation that shows the relationship between bond yields and their maturities. It assists in bond valuation by providing insights into the market's expectations of future interest rates and economic conditions. A normal yield curve, which slopes upward, indicates that longer-term bonds have higher yields compared to shorter-term bonds, reflecting the increased risk and longer time horizon associated with longer maturities. Conversely, an inverted yield curve, where short-term yields are higher than long-term yields, may signal economic uncertainty or a potential recession. By analyzing the shape and position of the yield curve, investors can make more informed decisions about the appropriate valuation of bonds, as it helps them understand the prevailing interest rate environment and the associated risks of holding bonds with different maturities."
#        }
#      ]
# }
#
#
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Extra data: line 11 column 1 (char 2099)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What are the different approaches to stock valuation mentioned in the text segment, and how do they differ from each other?",
#          "answer": "The text segment outlines several approaches to stock valuation, each with its unique methodology and focus. The first approach mentioned is the Dividend Discount Models (DDMs), which are used to value a stock by considering the present value of its expected future dividends. DDMs are particularly useful for companies that pay regular dividends, as they provide a direct link between the stock's price and the dividends it generates. The second approach is the Discounted Cash Flow (DCF) Model, which values a stock based on the present value of its expected future cash flows. Unlike DDMs, DCF models are not limited to dividend-paying companies and can be applied to any company that generates cash flows. The DCF model involves estimating the company's future cash flows and then discounting them back to their present value using a discount rate, which reflects the riskiness of those cash flows. The third approach mentioned is the valuation of Preferred Stock, which is a type of equity security that typically pays fixed dividends and has a higher claim on assets than common stock in the event of liquidation. Preferred stocks are often valued based on their dividend payments and the company's ability to pay those dividends. The fourth approach is the concept of Efficient Markets, which suggests that stock prices fully reflect all available information. According to this theory, it is impossible to consistently achieve higher returns than the overall market through stock selection or market timing, as prices always incorporate and reflect all relevant information. Each of these approaches offers a different perspective on stock valuation, and investors may choose one or a combination of them based on their investment goals, the characteristics of the stock, and their assessment of the market."
#        },
#        {
#          "question": "What is the significance of the historical picture of inflation and returns to bonds as discussed in the text segment?",
#          "answer": "The historical picture of inflation and returns to bonds is significant as it provides insights into the performance of the financial markets over time and helps investors understand the relationship between inflation and bond yields. Inflation refers to the general increase in prices and the decrease in purchasing power of money over time. It is an important factor to consider when investing in bonds, as it can impact the real returns that investors receive. Historically, periods of high inflation have been associated with lower bond yields, as investors demand higher returns to compensate for the loss of purchasing power. Conversely, periods of low inflation have been
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Unterminated string starting at: line 8 column 20 (char 2179)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the main focus of Chapter 13 in the provided text segment?",
#          "answer": "Chapter 13 primarily focuses on statistical analysis in finance. It covers various measures of center, spread, and position, as well as statistical distributions, probability distributions, data visualization, and the use of the R statistical analysis tool. The chapter aims to provide a comprehensive understanding of statistical concepts and their application in finance, which is essential for analyzing financial data, making informed decisions, and conducting research in the field."
#        },
#        {
#          "question": "What are the key topics covered in Chapter 13 of the provided text segment?",
#          "answer": "Chapter 13 of the provided text segment covers several key topics related to statistical analysis in finance. These topics include measures of center, which involve understanding the central tendency of data; measures of spread, which focus on the variability or dispersion of data; measures of position, which relate to the relative standing of data points; statistical distributions, which describe the probability of different outcomes; probability distributions, which provide a mathematical framework for predicting the likelihood of various events; data visualization and graphical displays, which help in presenting data in a clear and understandable manner; and the R statistical analysis tool, which is a software environment used for statistical computing and graphics. The chapter also includes a summary, key terms, multiple-choice questions, review questions, and problems to reinforce the concepts discussed."
#        }
#     ]
#
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [{
#
#         "question": "What is the purpose of regression analysis in finance as discussed in the text segment, and how does it apply to making predictions and prediction intervals?",
#
#         "answer": "Regression analysis in finance, as outlined in the text segment, serves as a critical tool for understanding and quantifying the relationships between variables. It is particularly useful in the context of financial markets, where analysts and investors seek to predict future trends and make informed decisions. The purpose of regression analysis in finance is multifaceted, encompassing the identification of correlations, the establishment of linear models, and the application of these models to real-world financial scenarios.
#
# The text segment highlights several key aspects of regression analysis in finance. Firstly, it discusses correlation analysis (14.1), which is the initial step in understanding the relationship between two or more variables. By examining the strength and direction of these relationships, analysts can determine whether a predictive model is feasible.
#
# Following correlation analysis, the text delves into linear regression analysis (14.2), which involves fitting a linear equation to observed data. This equation models the relationship between a dependent variable (often a financial metric like stock price or return) and one or more independent variables (such as economic indicators or company performance metrics). The goal is to find the best-fit line that minimizes the differences between the observed values and the values predicted by the model.
#
# The concept of the best-fit linear model (14.3) is crucial, as it represents the most accurate representation of the data within the context of the chosen variables. This model is then used to make predictions about future values of the dependent variable based on new or existing values of the independent variables.
#
# In finance, regression analysis has numerous applications (14.4), including risk assessment, portfolio management, and investment strategy development. By understanding the relationships between different financial variables, analysts can better estimate the risk and return associated with individual assets (15.1) and make more informed investment decisions.
#
# Finally, the text segment addresses the use of prediction intervals (14.6), which provide a range of values within which future observations are expected to fall with a certain level of confidence. These intervals are essential for assessing the uncertainty and potential variability in financial predictions, allowing investors to gauge the likelihood of different outcomes.
#
# In summary, regression analysis in finance is a powerful tool that enables analysts to model relationships between variables, make predictions, and assess the uncertainty of these predictions. By leveraging statistical techniques and tools like the R statistical analysis tool, finance professionals can gain deeper insights into market dynamics and enhance their decision
# Error processing chunk from Documents/PrinciplesofFinance-WEB.pdf: Invalid control character at: line 5 column 551 (char 737)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#        {
#          "question": "What is the Capital Asset Pricing Model (CAPM) and why is it important in the context of investment decisions?",
# ...
#         "answer": "Appealing to the US Supreme Court differs from appealing to the state supreme court primarily in the scope and nature of the cases that can be heard. The state supreme courts are the highest courts within their respective states and typically have the final say on most legal matters within their jurisdictions. Their rulings are generally considered final, except in cases where federal constitutional claims are involved. In such instances, appellants have the right to appeal to the US Supreme Court. The US Supreme Court, on the other hand, has the discretion to select the cases it wishes to hear, focusing on those that have significant legal or constitutional implications. This selective process allows the Supreme Court to address issues of national importance, resolve conflicts among different state courts, and interpret the Constitution. Appeals to the US Supreme Court are limited to cases that involve federal constitutional claims, meaning that the legal questions raised must pertain to the interpretation or application of the US Constitution. This distinction underscores the different roles played by the state supreme courts and the US Supreme Court within the American judicial system, with the former serving as the final arbiter of state law and the latter addressing broader constitutional issues that affect the entire nation."
#     }
# ]
#
#
# Error processing chunk from Documents/Legal Aspects of Corporate Management and Finance.pdf: Extra data: line 4 column 6 (char 1074)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  {
#         "question": "What is the role of the US District Court in the federal judicial system, and how many federal districts are there in the United States?",
#         "answer": "The US District Court serves as the trial court in the federal judicial system, which is uniform throughout the United States. There are multiple federal districts, with each state having at least one. The less populous states have one federal district, while more populous states like California, Texas, and New York have four federal districts each. The US District Court with the heaviest commercial docket is the US District Court for the Southern District of New York."
#     },
#     {
#         "question": "What is a writ of certiorari, and under what circumstances might it be issued by the US Supreme Court?",
#         "answer": "A writ of certiorari is a legal order issued by the US Supreme Court to review the decision of a lower court. It is a discretionary order, meaning the Supreme Court chooses which cases to review. The issuance of a writ of certiorari is typically reserved for cases that involve significant federal questions, particularly those that have the potential to resolve conflicting decisions from lower courts or address issues of national importance. When federal constitutional claims are made, an appeal to the US Supreme Court to issue a writ of certiorari remains a possibility, allowing the Supreme Court to provide a final resolution on matters of constitutional significance."
#     }
# ]
#
#
# Error processing chunk from Documents/Legal Aspects of Corporate Management and Finance.pdf: Extra data: line 4 column 6 (char 662)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#         {
#             "question": "How many district judges and magistrates are there in the Southern District of New York, and what types of cases do they commonly preside over?",
#             "answer": "The Southern District of New York, located in Manhattan, has a total of forty-four district judges and fifteen magistrates. These district judges are responsible for presiding over all federal trials, which include both criminal and civil cases. This means that any case that is brought before the federal court system within this district will be overseen by one of these judges. The role of the magistrates in this district, while not specified in detail in the provided text, typically involves handling preliminary matters, such as issuing warrants, setting bail, and presiding over misdemeanor cases. The district judges, due to their broader jurisdiction, also handle more complex and significant cases that may involve larger sums of money, more serious charges, or more intricate legal issues."
#         },
#         {
#             "question": "What is the role of the circuit courts of appeal in relation to the district courts, and how many circuits are there in the United States?",
#             "answer": "The circuit courts of appeal play a crucial role in the federal judicial system by serving as the appellate courts for cases that originate from the district courts. When a party involved in a case from a district court is dissatisfied with the decision, they have the right to appeal to the circuit court of appeal that has jurisdiction over the district court in question. The purpose of the circuit courts of appeal is to review the decisions made by the district courts to ensure that the law was applied correctly and that the proceedings were fair. If the appellate court finds that there were errors in the application of the law or procedural mistakes, it can reverse or modify the district court's decision. There are thirteen circuit courts of appeal in the United States, each overseeing the work of the district courts within its respective circuit. These circuits are geographically divided, with each one covering a specific region of the country, ensuring that the appellate review process is organized and efficient."
#         }
#     ]
#
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  {
#         "question": "Which states are represented by the US Court of Appeals for the Second Circuit, and what is its jurisdiction?",
#         "answer": "The US Court of Appeals for the Second Circuit represents New York, Connecticut, and Vermont. This court hears appeals from district courts within these states. Its jurisdiction extends to these three states, providing a higher level of judicial review for cases that have been decided in the district courts of New York, Connecticut, and Vermont. The Second Circuit plays a crucial role in the federal judicial system by ensuring that the district courts' decisions adhere to federal law and constitutional principles. It serves as an appellate court, meaning it reviews the decisions made by the district courts to ensure that the law was applied correctly and that the legal proceedings were fair. This court's decisions can significantly impact the legal landscape within these states, as it has the authority to affirm, reverse, or remand cases back to the district courts for further proceedings. The Second Circuit's rulings can also set important legal precedents that influence future cases within its jurisdiction."
#     },
#     {
#         "question": "What is the jurisdiction of the US Court of Appeals for the Ninth Circuit, and which states and territories does it cover?",
#         "answer": "The US Court of Appeals for the Ninth Circuit has jurisdiction over appeals from district courts in California, Oregon, Nevada, Montana, Washington, Idaho, Arizona, Alaska, Hawaii, and Guam. This court serves as an appellate body for these states and territories, reviewing decisions made by the district courts within their respective jurisdictions. The Ninth Circuit's jurisdiction is extensive, covering a significant portion of the western United States and the Pacific territories. By hearing appeals from these diverse regions, the Ninth Circuit plays a vital role in the federal judicial system, ensuring that the district courts' decisions comply with federal law and constitutional principles. The court's decisions can have a profound impact on the legal landscape within these states and territories, as it has the authority to affirm, reverse, or remand cases back to the district courts for further proceedings. The Ninth Circuit's rulings can also set important legal precedents that influence future cases within its jurisdiction, shaping the legal framework and guiding the interpretation of laws in these regions."
#     }
# ]
#
#
# Error processing chunk from Documents/Legal Aspects of Corporate Management and Finance.pdf: Extra data: line 4 column 6 (char 1186)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  [
#         {
#             "question": "What is the composition of the US Supreme Court, and how many justices does it include?",
#             "answer": "The US Supreme Court, which oversees all federal courts, is composed of nine justices. This includes the Chief Justice of the United States and eight Associate Justices. The number of justices on the Supreme Court is not a constitutional requirement; Congress has the authority to change this number. The justices serve lifetime appointments, ensuring their independence from political pressures and allowing them to make decisions based solely on their interpretation of the law."
#         },
#         {
#             "question": "What are the specialized courts within the federal judicial system, and what are their specific functions?",
#             "answer": "Within the federal judicial system, there are several specialized courts, each with distinct functions. The US Tax Court is responsible for hearing cases related to federal tax disputes, providing a forum for taxpayers to contest tax deficiencies determined by the Internal Revenue Service. The Court of Customs and Patent Appeals deals with cases involving customs duties and patent law, ensuring that regulations and laws related to these areas are properly enforced. The Court of Claims handles cases involving claims against the United States government, including those related to government contracts, property, and other financial matters. These specialized courts ensure that cases within their respective domains are handled by judges with the appropriate expertise and experience."
#         }
#     ]
#
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  {
#         "question": "How many cases did the Supreme Court hear in 2008, and what was the total number of petitions submitted that year?",
#         "answer": "In 2008, the Supreme Court heard arguments in only 87 cases out of the numerous petitions submitted that year. The total number of petitions submitted to the Supreme Court in 2008 was over 7,000, not including thousands of petitions from prisoners. This indicates that the Supreme Court has selective control over its docket, hearing only a tiny fraction of the cases that are submitted to it."
#      },
#      {
#         "question": "Does the Supreme Court sit in panels, and how are cases typically heard by the justices?",
#         "answer": "The Supreme Court does not sit in panels. All the justices hear and consider each case together, unless a justice has a conflict of interest and must withdraw from hearing the case. This means that every justice on the Supreme Court participates in the deliberation and decision-making process for each case, ensuring a unified and collective approach to the interpretation and application of the law."
#      }
# ]
#
#
# Error processing chunk from Documents/Legal Aspects of Corporate Management and Finance.pdf: Extra data: line 4 column 7 (char 561)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
#  "question": "How are federal judges, including Supreme Court justices, appointed and what distinguishes their tenure from that of state judges?",
#      "answer": "Federal judges, including Supreme Court justices, are appointed through a process that begins with the nomination by the President of the United States. Following the nomination, the Senate must confirm the appointment. This process ensures a system of checks and balances, where both the executive and legislative branches have a role in the selection of federal judges. Once confirmed, federal judges, unlike their state counterparts, are appointed for life. This means they can serve on the bench indefinitely, unless they choose to retire voluntarily or are removed through the process of impeachment. The lifetime tenure of federal judges is designed to insulate them from political pressures and allow them to make decisions based solely on the law and their interpretation of the Constitution, without fear of losing their position due to political changes. In contrast, state judges are typically elected and serve for a fixed term of years. This difference in the method of appointment and the duration of service reflects the distinct roles and responsibilities of federal and state judicial systems within the United States."
#
#     {
#         "question": "What are the primary functions of trial courts and appellate courts in the United States judicial system?",
#         "answer": "In the United States judicial system, trial courts and appellate courts serve distinct but complementary functions. Trial courts, also known as courts of first instance, are where cases are initially heard and decided. These courts are responsible for examining the evidence, hearing witness testimony, and making determinations of fact. The primary function of trial courts is to resolve disputes by applying the law to the facts presented in each case. They are the first level of the judiciary where parties present their arguments, evidence, and legal claims. Once a trial court has made a decision, the parties have the right to appeal the decision to an appellate court if they believe there has been a legal error that affected the outcome of the case. Appellate courts, on the other hand, do not conduct trials or hear new evidence. Instead, their main function is to review the proceedings and decisions of trial courts to ensure that the law was applied correctly and that the legal process was fair. Appellate courts examine the record of the trial court proceedings, including transcripts, evidence, and legal briefs submitted by the parties. They focus on questions of law rather than questions of fact. Appellate courts can affirm the trial court's decision, reverse it, or remand the case back to the trial court for further proceedings. In some instances, appellate courts can also create new law through their interpretations of the Constitution and statutes. The appellate process is a critical component of the judicial system, providing a mechanism for correcting errors and ensuring the consistent application of the law across different cases."
#     }
#
# Error processing chunk from Documents/Legal Aspects of Corporate Management and Finance.pdf: Extra data: line 1 column 12 (char 11)
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv
# Updated detailed tracker: LMForge_RUN04_DGX_SPARK_microsoft-Phi-4-mini-instruct/qa_run_tracker_detailed.csv

# %%
import shutil
import os
import json
import pandas as pd
def load_data(chunk_size):
    path = f"../Spring25/Generate_Paragraphs/Results/extracted_chunks_{chunk_size}_overlap.json"
    if not os.path.exists(path):
        print(f"Missing input file: {path}, skipping.")
        return None
    with open(path, "r", encoding="utf-8") as file:
        return json.load(file)
    

chunk_sizes = [128, 256, 512, 1024]
# check how many chunks are in the file for each chunk size

for chunk_size in chunk_sizes:
    chunk_data = load_data(chunk_size)
    if chunk_data is not None:
        total_chunks = sum(len(chunks) for chunks in chunk_data.values())
        print(f"Total chunks for chunk size {chunk_size}: {total_chunks}")
    else:
        print(f"No data found for chunk size {chunk_size}")
# Out:
# Total chunks for chunk size 128: 6996
# Total chunks for chunk size 256: 3618
# Total chunks for chunk size 512: 1824
# Total chunks for chunk size 1024: 910

# %% [markdown]
# ## Statistical Significance
#
# #### MANOVA ASSUMPTIONS
# - Multivariate Normality dependent variables should be jointly normally distributed
# - Homogeneity of variance-covariance matrices
# - Independence of observations
# - No multicollinearity
# - Linearity
# - Outliers

# %%
from scipy.stats import chi2 , probplot
from sklearn.covariance import MinCovDet
import numpy as np
import matplotlib.pyplot as plt
import pingouin as pg
import os
import pandas as pd
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from statsmodels.multivariate.manova import MANOVA
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from skbio.stats.distance import permanova, DistanceMatrix
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA



# Load the CSV files
output_base = "LMForge_RUN02/Generated_Results/DeepSeek-R1-0528-Qwen3-8B"
if os.path.exists(f"{output_base}/scores.csv"):
    print(f"File {f"{output_base}/scores.csv"} exists.")
else:
    print(f"File {f"{output_base}/scores.csv"} does not exist. Please check the path.")
# Read the CSV file
scores_df = pd.read_csv(f"{output_base}/scores.csv")
# drop duplicates
scores_df = scores_df.drop_duplicates(subset=["chunk_size", "max_tokens"], keep="first").drop(columns=["elapsed_time","questions_num"])

dv_columns = [
    "rouge1", "rouge2", "rougeL", "rougeLsum",
    "bert_score_P", "bert_score_R", "bert_score_F1",
    "sts_score"
]
# Out:
#   Cell In[15], line 24
#     print(f"File {f"{output_base}/scores.csv"} exists.")
#                     ^
# SyntaxError: f-string: expecting '}'

# %%
# Select only the dependent variables (DVs)
X = scores_df[dv_columns].dropna()

# Compute robust Mahalanobis distances
robust_cov = MinCovDet().fit(X)
mahalanobis_distances = robust_cov.mahalanobis(X)

# Chi-squared Q-Q plot
probplot(mahalanobis_distances, dist="chi2", sparams=(len(dv_columns),), plot=plt)
plt.title("Q-Q Plot of Mahalanobis Distances")
plt.show()

# Formal multivariate normality test (Henze-Zirkler's)
normality_test = pg.multivariate_normality(scores_df[dv_columns], alpha=0.05)
print("Henze-Zirkler Test:\n", normality_test)
# Out:
# File LMForge_RUN02/Generated_Results/LLAMA3_1/scores.csv exists.
# Henze-Zirkler Test:
#  HZResults(hz=1.0795278119755913, pval=1.5825002782747915e-06, normal=False)

# %%
# Calculate the threshold for outliers
threshold = chi2.ppf(0.99, df=len(dv_columns))
outliers = mahalanobis_distances > threshold
# Print the number of outliers
print(f"Outlier count: {np.sum(outliers)}")
# identifying the outliers
outlier_indices = np.where(outliers)[0]
outlier_rows = scores_df.iloc[outlier_indices]
print("Outlier rows:")
print(outlier_rows)
# Out:
# Outlier count: 5
# Outlier rows:
#     chunk_size  max_tokens    rouge1    rouge2    rougeL  rougeLsum  \
# 0          128         128  0.240665  0.171811  0.209919   0.229688
# 3          128        1024  0.351167  0.231052  0.284325   0.332217
# 4          128        2048  0.347461  0.221321  0.275704   0.326842
# 15        1024         128  0.031999  0.021180  0.028436   0.031318
# 17        1024         512  0.081810  0.059997  0.070784   0.080223
#
#     bert_score_P  bert_score_R  bert_score_F1  sts_score substring_date
# 0       0.714532      0.440610       0.539756   0.559266  LMForge_RUN02
# 3       0.691136      0.520246       0.585593   0.609433  LMForge_RUN02
# 4       0.679636      0.520178       0.581982   0.618118  LMForge_RUN02
# 15      0.593533      0.313629       0.406797   0.360901  LMForge_RUN02
# 17      0.637666      0.376273       0.467231   0.447940  LMForge_RUN02

# %%
## homogeneity of covariance matrices 
# Box's M test
scores_df["group"] = scores_df["chunk_size"].astype(str)

# Then re-clean and re-test
df_clean = scores_df.dropna(subset=dv_columns + ["group"])
box_m = pg.box_m(data=df_clean, dvs=dv_columns, group='group')
print("Box’s M Test:\n", box_m)
# Out:
# Box’s M Test:
#       Chi2     df  pval  equal_cov
# box   inf  108.0   0.0      False
# /opt/anaconda3/lib/python3.12/site-packages/pingouin/multivariate.py:386: RuntimeWarning: divide by zero encountered in log
#   u = -2 * (1 - c) * np.log(M)

# %%
threshold = chi2.ppf(0.999, df=X.shape[1])  # 99.9% cutoff
outlier_flags = mahalanobis_distances > threshold
num_outliers = np.sum(outlier_flags)

# summary of outlier results
outlier_summary = pd.DataFrame([{
    "Total Observations": len(mahalanobis_distances),
    "Outliers Detected (p < 0.001)": num_outliers,
    "Percentage Outliers": 100 * num_outliers / len(mahalanobis_distances)
}])
print(outlier_summary)
# Out:
#    Total Observations  Outliers Detected (p < 0.001)  Percentage Outliers
# 0                  20                              5                 25.0

# %%
# Check correlation between DVs
sns.heatmap(scores_df[dv_columns].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation between DVs")
plt.show()

# %%
# Check for multicollinearity

# Add a constant to the model
X_with_const = add_constant(X)
# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) for i in range(X_with_const.shape[1])]
print(vif_data)
# Out:
#          feature           VIF
# 0          const   8996.863254
# 1         rouge1  88353.609271
# 2         rouge2   4995.350022
# 3         rougeL  12965.565541
# 4      rougeLsum  62530.524231
# 5   bert_score_P    193.709623
# 6   bert_score_R   4317.033541
# 7  bert_score_F1   4684.069453
# 8      sts_score    193.722995

# %%
# Define DVs
dv_columns = [
    "rouge1", "rouge2", "rougeL", "rougeLsum",
    "bert_score_P", "bert_score_R", "bert_score_F1", "sts_score"
]

# Create group variable
scores_df["group"] = scores_df["chunk_size"].astype(str)

# Drop missing
df_simple = scores_df.dropna(subset=dv_columns + ["group"])

# Create MANOVA formula
formula_simple = " + ".join(dv_columns) + " ~ group"

# Fit MANOVA
maov_simple = MANOVA.from_formula(formula_simple, data=df_simple)
print(maov_simple.mv_test())
# Out:
#                    Multivariate linear model
# ================================================================
#
# ----------------------------------------------------------------
#        Intercept          Value   Num DF Den DF  F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda    0.0002 8.0000 9.0000 5157.1422 0.0000
#          Pillai's trace    0.9998 8.0000 9.0000 5157.1422 0.0000
#  Hotelling-Lawley trace 4584.1264 8.0000 9.0000 5157.1422 0.0000
#     Roy's greatest root 4584.1264 8.0000 9.0000 5157.1422 0.0000
# ----------------------------------------------------------------
#
# ----------------------------------------------------------------
#          group           Value    Num DF  Den DF F Value  Pr > F
# ----------------------------------------------------------------
#           Wilks' lambda   0.0000 24.0000 26.7040  44.8593 0.0000
#          Pillai's trace   2.6072 24.0000 33.0000   9.1262 0.0000
#  Hotelling-Lawley trace 277.6527 24.0000 13.4545  95.1217 0.0000
#     Roy's greatest root 168.6529  8.0000 11.0000 231.8977 0.0000
# ================================================================

# %%
# Type III ANOVA

# Fit the model using OLS
def type_3(formula, data):
    """
    Perform Type III ANOVA using the given formula and data.
    """
    model = ols(formula, data=data).fit()
    anova_results = anova_lm(model, typ=3)
    return anova_results

# Perform Type III ANOVA for each dependent variable
results = []
for column in dv_columns:
    formula = f"{column} ~ group"
    anova_results = type_3(formula, df_clean)
    print(f"ANOVA results for {column}:\n", anova_results)
    results.append((column, anova_results))

# results
anova_results_dict = {column: result for column, result in results}
# Out:
# ANOVA results for rouge1:
#               sum_sq    df          F    PR(>F)
# Intercept  0.029093   1.0  13.816819  0.001873
# group      0.178835   3.0  28.310453  0.000001
# Residual   0.033690  16.0        NaN       NaN
# ANOVA results for rouge2:
#               sum_sq    df          F    PR(>F)
# Intercept  0.016336   1.0  16.238389  0.000970
# group      0.072025   3.0  23.865055  0.000004
# Residual   0.016096  16.0        NaN       NaN
# ANOVA results for rougeL:
#               sum_sq    df          F        PR(>F)
# Intercept  0.022291   1.0  17.462634  7.092123e-04
# group      0.113757   3.0  29.704922  8.945681e-07
# Residual   0.020424  16.0        NaN           NaN
# ANOVA results for rougeLsum:
#               sum_sq    df          F    PR(>F)
# Intercept  0.028120   1.0  14.524290  0.001536
# group      0.156535   3.0  26.950182  0.000002
# Residual   0.030978  16.0        NaN       NaN
# ANOVA results for bert_score_P:
#               sum_sq    df            F        PR(>F)
# Intercept  2.036713   1.0  6344.848534  3.150824e-22
# group      0.015183   3.0    15.765818  4.898914e-05
# Residual   0.005136  16.0          NaN           NaN
# ANOVA results for bert_score_R:
#               sum_sq    df           F        PR(>F)
# Intercept  0.685507   1.0  536.615891  9.825047e-14
# group      0.051519   3.0   13.443050  1.222859e-04
# Residual   0.020439  16.0         NaN           NaN
# ANOVA results for bert_score_F1:
#               sum_sq    df            F        PR(>F)
# Intercept  1.071924   1.0  1195.929171  1.823074e-16
# group      0.036532   3.0    13.585891  1.152391e-04
# Residual   0.014341  16.0          NaN           NaN
# ANOVA results for sts_score:
#               sum_sq    df           F        PR(>F)
# Intercept  0.920708   1.0  830.616116  3.222891e-15
# group      0.082794   3.0   24.897544  2.876530e-06
# Residual   0.017735  16.0         NaN           NaN

# %%
scores_df["group"] = scores_df["chunk_size"].astype(str)
df_simple = scores_df.dropna(subset=dv_columns + ["group"])

# Create distance matrix and group labels reference: https://scikit.bio/docs/dev/generated/skbio.stats.distance.html
X = df_simple[dv_columns].values
group_labels = df_simple["group"].values
distance_matrix = DistanceMatrix(squareform(pdist(X, metric='euclidean')))

# Run PERMANOVA
results = permanova(distance_matrix, grouping=group_labels, permutations=999)
print("PERMANOVA results for chunk_size groups:")
print(results)



scores_df["group2"] = scores_df[["max_tokens"]].astype(str)
# Create distance matrix and group labels
X2 = scores_df[dv_columns].values
distance_matrix2 = DistanceMatrix(squareform(pdist(X2, metric='euclidean')))
# Run PERMANOVA for the second group
results2 = permanova(distance_matrix2, grouping=scores_df["group2"].values, permutations=999)
print("PERMANOVA results for max_tokens groups:")
print(results2)
# Out:
# PERMANOVA results for chunk_size groups:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      20
# number of groups                  4
# test statistic            23.744764
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object
# PERMANOVA results for max_tokens groups:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      20
# number of groups                  5
# test statistic             0.736644
# p-value                       0.565
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %%
# PCA + MANOVA 
scores_df["group"] = scores_df["chunk_size"].astype(str)
df_clean = scores_df.dropna(subset=dv_columns + ["group"])

# Standardize the dependent variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_clean[dv_columns])

# Perform PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Add principal components to the dataframe
df_clean["PC1"] = X_pca[:, 0]
df_clean["PC2"] = X_pca[:, 1]

# Run MANOVA on the first two principal components
from statsmodels.multivariate.manova import MANOVA
maov_pca = MANOVA.from_formula("PC1 + PC2 ~ group", data=df_clean)
manova_pca_results = maov_pca.mv_test()
print("MANOVA results on PCA components:\n", manova_pca_results)
# Plot PCA results
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_clean, x="PC1", y="PC2", hue="group", style="group")
plt.title("PCA of Dependent Variables by Chunk Size")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Chunk Size")
plt.show()
# Out:
# MANOVA results on PCA components:
#                   Multivariate linear model
# ============================================================
#
# ------------------------------------------------------------
#        Intercept        Value  Num DF  Den DF F Value Pr > F
# ------------------------------------------------------------
#           Wilks' lambda 0.2891 2.0000 15.0000 18.4387 0.0001
#          Pillai's trace 0.7109 2.0000 15.0000 18.4387 0.0001
#  Hotelling-Lawley trace 2.4585 2.0000 15.0000 18.4387 0.0001
#     Roy's greatest root 2.4585 2.0000 15.0000 18.4387 0.0001
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#          group          Value  Num DF  Den DF F Value Pr > F
# ------------------------------------------------------------
#           Wilks' lambda 0.0639 6.0000 30.0000 14.7822 0.0000
#          Pillai's trace 1.4756 6.0000 32.0000 15.0083 0.0000
#  Hotelling-Lawley trace 6.2083 6.0000 18.3256 15.0992 0.0000
#     Roy's greatest root 4.1953 3.0000 16.0000 22.3750 0.0000
# ============================================================

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='chunk_size', y='bert_score_F1', hue='max_tokens', data=scores_df, palette="Set2")
plt.xlabel("Chunk Size")
plt.ylabel("BERTScore F1")
plt.xticks(rotation=45)
plt.legend(title="Max Tokens")
plt.grid(axis='y')
plt.tight_layout()
plt.figure(figsize=(12, 6))
sns.lineplot(data=scores_df, x='chunk_size', y='bert_score_F1', hue='max_tokens', marker='o')
plt.xlabel("Chunk Size")
plt.ylabel("BERTScore F1")
plt.title("BERTScore F1 by Chunk Size and Max Tokens")
plt.xticks(rotation=45)
plt.legend(title="Max Tokens")
plt.grid()

# %%
from itertools import combinations
from scipy.spatial.distance import pdist, squareform

pairwise_results = []
scores_df["group"] = scores_df["chunk_size"].astype(str)

# Looping through the combinations of groups
for grp1, grp2 in combinations(scores_df["group"].unique(), 2):
    subset = scores_df[scores_df["group"].isin([grp1, grp2])].copy()
    subset = subset.reset_index(drop=True)
    
    # Distance matrix
    X_pair = subset[dv_columns].values
    distance_array = squareform(pdist(X_pair, metric='euclidean'))
    ids = [str(i) for i in subset.index]
    distance_matrix = DistanceMatrix(distance_array, ids=ids)
    
    # DataFrame with group labels
    grouping_df = pd.DataFrame({'group': subset["group"].values}, index=ids)
    
    # PERMANOVA 
    result = permanova(distance_matrix, grouping=grouping_df, column='group', permutations=999)
    
    pairwise_results.append({
        "Group 1": grp1,
        "Group 2": grp2,
        "Pseudo-F": result["test statistic"],
        "p-value": result["p-value"]
    })

pairwise_df = pd.DataFrame(pairwise_results)
print(pairwise_df)
# Out:
#   Group 1 Group 2   Pseudo-F  p-value
# 0     128     256   7.242994    0.029
# 1     128     512  36.159047    0.007
# 2     128    1024  75.109721    0.009
# 3     256     512   7.081500    0.030
# 4     256    1024  23.854621    0.010
# 5     512    1024   6.190598    0.035

# %%
# Compute group means
group_means = scores_df.groupby('chunk_size')[dv_columns].mean().mean(axis=1).sort_index()
print("Group Means:")
print(group_means)

differences = []
# Calculate differences between each pair of groups
for (grp1, grp2) in combinations(group_means.index, 2):
    diff = group_means[grp2] - group_means[grp1]
    differences.append({
        "Group 1": grp1,
        "Group 2": grp2,
        "Mean Difference": diff
    })

differences_df = pd.DataFrame(differences)
print("Mean Differences between Groups:")
print(differences_df)
# Out:
# Group Means:
# chunk_size
# 128     0.436578
# 256     0.381648
# 512     0.321881
# 1024    0.271981
# dtype: float64
# Mean Differences between Groups:
#    Group 1  Group 2  Mean Difference
# 0      128      256        -0.054930
# 1      128      512        -0.114697
# 2      128     1024        -0.164598
# 3      256      512        -0.059767
# 4      256     1024        -0.109668
# 5      512     1024        -0.049901

# %%
# Step 1: Compute group means per DV
group_means = scores_df.groupby('chunk_size')[dv_columns].mean().sort_index()
print("Group Means:")
print(group_means)

# Step 2: Compute pairwise mean differences for each DV
differences = []
chunk_sizes = group_means.index.tolist()

for dv in dv_columns:
    for grp1, grp2 in combinations(chunk_sizes, 2):
        diff = group_means.loc[grp2, dv] - group_means.loc[grp1, dv]
        differences.append({
            "Dependent Variable": dv,
            "Group 1": grp1,
            "Group 2": grp2,
            "Mean Difference": diff
        })

# Step 3: Convert to DataFrame
differences_df = pd.DataFrame(differences)
print("Mean Differences between Groups for Each DV:")
print(differences_df)
# Out:
# Group Means:
#               rouge1    rouge2    rougeL  rougeLsum  bert_score_P  \
# chunk_size
# 128         0.325832  0.216365  0.266557   0.308374      0.696190
# 256         0.231468  0.158992  0.191592   0.223323      0.709704
# 512         0.138051  0.100932  0.118642   0.134836      0.695675
# 1024        0.076280  0.057159  0.066770   0.074994      0.638234
#
#             bert_score_R  bert_score_F1  sts_score
# chunk_size
# 128             0.501457       0.575429   0.602425
# 256             0.445231       0.540396   0.552478
# 512             0.392216       0.495966   0.498733
# 1024            0.370272       0.463017   0.429117
# Mean Differences between Groups for Each DV:
#    Dependent Variable  Group 1  Group 2  Mean Difference
# 0              rouge1      128      256        -0.094364
# 1              rouge1      128      512        -0.187781
# 2              rouge1      128     1024        -0.249552
# 3              rouge1      256      512        -0.093417
# 4              rouge1      256     1024        -0.155188
# 5              rouge1      512     1024        -0.061771
# 6              rouge2      128      256        -0.057373
# 7              rouge2      128      512        -0.115433
# 8              rouge2      128     1024        -0.159206
# 9              rouge2      256      512        -0.058060
# 10             rouge2      256     1024        -0.101833
# 11             rouge2      512     1024        -0.043773
# 12             rougeL      128      256        -0.074965
# 13             rougeL      128      512        -0.147915
# 14             rougeL      128     1024        -0.199786
# 15             rougeL      256      512        -0.072950
# 16             rougeL      256     1024        -0.124821
# 17             rougeL      512     1024        -0.051872
# 18          rougeLsum      128      256        -0.085051
# 19          rougeLsum      128      512        -0.173538
# 20          rougeLsum      128     1024        -0.233380
# 21          rougeLsum      256      512        -0.088487
# 22          rougeLsum      256     1024        -0.148329
# 23          rougeLsum      512     1024        -0.059842
# 24       bert_score_P      128      256         0.013515
# 25       bert_score_P      128      512        -0.000514
# 26       bert_score_P      128     1024        -0.057956
# 27       bert_score_P      256      512        -0.014029
# 28       bert_score_P      256     1024        -0.071470
# 29       bert_score_P      512     1024        -0.057441
# 30       bert_score_R      128      256        -0.056226
# 31       bert_score_R      128      512        -0.109241
# 32       bert_score_R      128     1024        -0.131185
# 33       bert_score_R      256      512        -0.053015
# 34       bert_score_R      256     1024        -0.074959
# 35       bert_score_R      512     1024        -0.021944
# 36      bert_score_F1      128      256        -0.035033
# 37      bert_score_F1      128      512        -0.079463
# 38      bert_score_F1      128     1024        -0.112412
# 39      bert_score_F1      256      512        -0.044430
# 40      bert_score_F1      256     1024        -0.077379
# 41      bert_score_F1      512     1024        -0.032949
# 42          sts_score      128      256        -0.049947
# 43          sts_score      128      512        -0.103692
# 44          sts_score      128     1024        -0.173308
# 45          sts_score      256      512        -0.053745
# 46          sts_score      256     1024        -0.123361
# 47          sts_score      512     1024        -0.069616

# %%
from scipy.stats import ttest_ind
from itertools import combinations
from statsmodels.stats.multitest import multipletests

# Pairwise t-tests for each dependent variable
results = []
for dv in dv_columns:
    for grp1, grp2 in combinations(scores_df["chunk_size"].unique(), 2):
        vals1 = scores_df[scores_df["chunk_size"] == grp1][dv]
        vals2 = scores_df[scores_df["chunk_size"] == grp2][dv]
        t_stat, p_val = ttest_ind(vals1, vals2, equal_var=False)
        results.append({
            "Outcome": dv,
            "Group 1": grp1,
            "Group 2": grp2,
            "t-statistic": t_stat,
            "raw p-value": p_val
        })

ttest_df = pd.DataFrame(results)

# Applying the FDR (Benjamini-Hochberg) correction
reject, fdr_pvals, sidak_thresh, bonf_thresh = multipletests(ttest_df["raw p-value"], method='fdr_bh')
ttest_df["FDR (BH) p-value"] = fdr_pvals
ttest_df["Significant (FDR < 0.05)"] = reject

# results
print(ttest_df.head())
ttest_df.to_csv("pairwise_ttests_fdr.csv", index=False)
# Out:
#   Outcome  Group 1  Group 2  t-statistic  raw p-value  FDR (BH) p-value  \
# 0  rouge1      128      256     2.851769     0.022036          0.037495
# 1  rouge1      128      512     6.401473     0.000212          0.001272
# 2  rouge1      128     1024     9.856474     0.000029          0.000346
# 3  rouge1      256      512     2.891892     0.021223          0.037495
# 4  rouge1      256     1024     5.406126     0.001538          0.004407
#
#    Significant (FDR < 0.05)
# 0                      True
# 1                      True
# 2                      True
# 3                      True
# 4                      True
